# %% [markdown]
# <a href="https://colab.research.google.com/github/Togundarr/Webby/blob/main/Weather_Predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
weather = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3598910.csv', index_col = 'DATE')

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2024-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   8.50
# 2024-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.09
# 2024-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  10.74
# 2024-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  12.75
# 2024-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  10.51
#
# ...

# %%
weather.shape[0]
# Out:
# 19760

# %%
weather.apply(pd.isnull).sum()
# Out:
# STATION        0
# NAME           0
# ACMH       10145
# ACSH       10144
# AWND        5115
# FMTM        9636
# PGTM        7493
# PRCP           0
# SNOW           0
# SNWD           2
# TAVG       13123
# TMAX           0
# TMIN           0
# TSUN       19729
# WDF1       10149
# WDF2        9617
# WDF5        9700
# WDFG       14639
# WDFM       19759
# WESD       13689
# WSF1       10146
# WSF2        9617
# WSF5        9701
# WSFG       12297
# WSFM       19759
# WT01       12445
# WT02       18472
# WT03       18438
# WT04       19415
# WT05       19396
# WT06       19578
# WT07       19652
# WT08       15813
# WT09       19620
# WT11       19746
# WT13       17575
# WT14       18873
# WT15       19718
# WT16       13183
# WT17       19700
# WT18       18593
# WT19       19759
# WT21       19755
# WT22       19711
# WV01       19759
# dtype: int64

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]*100
# Out:
# STATION     0.000000
# NAME        0.000000
# ACMH       51.341093
# ACSH       51.336032
# AWND       25.885628
# FMTM       48.765182
# PGTM       37.920040
# PRCP        0.000000
# SNOW        0.000000
# SNWD        0.010121
# TAVG       66.411943
# TMAX        0.000000
# TMIN        0.000000
# TSUN       99.843117
# WDF1       51.361336
# WDF2       48.669028
# WDF5       49.089069
# WDFG       74.084008
# WDFM       99.994939
# WESD       69.276316
# WSF1       51.346154
# WSF2       48.669028
# WSF5       49.094130
# WSFG       62.231781
# WSFM       99.994939
# WT01       62.980769
# WT02       93.481781
# WT03       93.309717
# WT04       98.254049
# WT05       98.157895
# WT06       99.078947
# WT07       99.453441
# WT08       80.025304
# WT09       99.291498
# WT11       99.929150
# WT13       88.942308
# WT14       95.511134
# WT15       99.787449
# WT16       66.715587
# WT17       99.696356
# WT18       94.094130
# WT19       99.994939
# WT21       99.974696
# ...

# %%
columns_needed = weather.columns[weather.apply(pd.isnull).sum() ==0]

# %%
columns_needed
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'TMAX', 'TMIN'], dtype='object')

# %%
weather=weather[columns_needed].copy()
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  TMAX  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    28
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    31
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0    38
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    31
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    35
# ...                 ...                               ...   ...   ...   ...
# 2024-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.19   0.0    42
# 2024-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    43
# 2024-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    46
# 2024-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    45
# 2024-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    42
#
#             TMIN
# DATE
# 1970-01-01    22
# ...

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.0
# NAME       0.0
# PRCP       0.0
# SNOW       0.0
# TMAX       0.0
# TMIN       0.0
# dtype: float64

# %%
weather['SNOW'].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather.dtypes
# Out:
# STATION     object
# NAME        object
# PRCP       float64
# SNOW       float64
# TMAX         int64
# TMIN         int64
# dtype: object

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2024-01-28', '2024-01-29', '2024-01-30', '2024-01-31',
#                '2024-02-01', '2024-02-02', '2024-02-03', '2024-02-04',
#                '2024-02-05', '2024-02-06'],
#               dtype='datetime64[ns]', name='DATE', length=19760, freq=None)

# %%
weather.index.year
# Out:
# Int64Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#             ...
#             2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024],
#            dtype='int64', name='DATE', length=19760)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024     37
# Name: DATE, dtype: int64

# %%
weather["PREDICTTMAX"] = weather.shift(-1)["TMAX"]

# %%
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  TMAX  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    28
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    31
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0    38
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    31
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    35
# ...                 ...                               ...   ...   ...   ...
# 2024-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.19   0.0    42
# 2024-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    43
# 2024-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    46
# 2024-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    45
# 2024-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    42
#
#             TMIN  PREDICTTMAX
# DATE
# ...

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  TMAX  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    28
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    31
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0    38
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    31
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    35
# ...                 ...                               ...   ...   ...   ...
# 2024-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.19   0.0    42
# 2024-02-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    43
# 2024-02-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    46
# 2024-02-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    45
# 2024-02-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0    42
#
#             TMIN  PREDICTTMAX
# DATE
# ...

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(['PREDICTTMAX', 'NAME', 'STATION'])]

# %%
predictors
# Out:
# Index(['PRCP', 'SNOW', 'TMAX', 'TMIN'], dtype='object')

# %%
def backtest(weather, model, predictors, start=3650, step=90):
  all_predictions = []

  for i in range(start, weather.shape[0], step):
    train = weather.iloc[:i,:]
    test = weather.iloc[i:(i+step),:]

    model.fit(train[predictors], train['PREDICTTMAX'])

    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index)
    combined = pd.concat([test['PREDICTTMAX'], preds], axis=1)
    combined.columns = ['ACTUAL', 'PREDICTION']
    combined['DIFF'] = (combined['PREDICTION'] - combined['ACTUAL']).abs()

    all_predictions.append(combined)
  return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             ACTUAL  PREDICTION       DIFF
# DATE
# 1979-12-30    43.0   50.206285   7.206285
# 1979-12-31    42.0   43.643677   1.643677
# 1980-01-01    41.0   41.546777   0.546777
# 1980-01-02    36.0   43.932036   7.932036
# 1980-01-03    30.0   40.170777  10.170777
# ...            ...         ...        ...
# 2024-02-02    43.0   47.450025   4.450025
# 2024-02-03    46.0   45.553731   0.446269
# 2024-02-04    45.0   45.869840   0.869840
# 2024-02-05    42.0   45.421248   3.421248
# 2024-02-06     NaN   42.530969        NaN
#
# [16110 rows x 3 columns]
